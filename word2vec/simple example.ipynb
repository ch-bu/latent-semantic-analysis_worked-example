# %% [markdown]
# ## First example of word2vec

# %%
from gensim.models import Word2Vec
from gensim.models.ldamodel import LdaModel
from gensim import corpora
import spacy
import pandas as pd

# %%
# Load german spacy model
nlp = spacy.load('de_core_news_sm')

# Read and process christmas carol
# Read christmas carol data set
#with open('../datasets/christmas_carol.txt', 'r') as dickens:
#    the_book = dickens.read().decode('utf-8')
    
#doc = nlp(the_book)

# %%
# Read data
cognitive_load_data = pd.read_csv("../datasets/clt.csv", sep=",", encoding = "utf-8")

# Store all texts in long string
cognitive_load_long_string = ""

# Loop over every text
for document in cognitive_load_data["text"]:
    cognitive_load_long_string += document
    
doc = nlp(cognitive_load_long_string)

# %%
# Create corpus from data
documents = []

# Loop over every sentence
for sentence in doc.sents:
    tokens_in_sentence = []
    # Get every token
    for token in sentence:
        if token.is_alpha and token.is_stop != True and token.pos_ in ['NOUN']:
            tokens_in_sentence.append(token.lemma_.lower())
            
    # Add new sentence to documents
    documents.append(tokens_in_sentence)    

# Build dictionary from documents
dictionary = corpora.Dictionary(documents)

# Create corpus
corpus = [dictionary.doc2bow(sentence) for sentence in documents]

# %%
# Train word2vec
model = Word2Vec(documents, min_count=5)

# %%
print(documents)
# Out:
# [[u'lernproze\xdf', u'arbeitsged\xe4chtnis', u'kurzzeitged\xe4chtnis'], [u'arbeitsged\xe4chtnis', u'anstrengung', u'k\xf6rper', u'ressourcenkapazit\xe4t', u'verf\xfcgung'], [u'ph\xe4nomen', u'fokus'], [u'belastung', u'arbeitsged\xe4chtnisses'], [u'faktor', u'arbeitsspeicher', u'reizen', u'alltag', u'reaktion', u'reizen', u'bedeutung'], [u'beispiel', u'verarbeitung', u'reiz'], [u'stra\xdfenverkehr', u'voraussetzung', u'reizen', u'belastung', u'reizen', u'lernproze\xdf'], [u'grund', u'bibliothek', u'rede', u'l\xe4rmbel\xe4stigung'], [u'lernen', u'input', u'formen', u'text', u'langzeitged\xe4chtnis'], [u'lernprozess', u'platzen', u'input'], [u'einfluss', u'reizen', u'lernerfolg'], [], [u'einwirkung', u'reiz', u'lernende', u'arbeitsspeicher', u'fallen', u'reiz', u'arbeitsspeicher'], [u'stress', u'gedanke', u'beispiel'], [u'einflussfaktoren', u'lernerfolg', u'vorwissen', u'vorstellungsverm\xf6gen'], [u'faktor', u'inhalt', u'arbeitsspeicher', u'langzeitged\xe4chtnis'], [u'theorie', u'bildungswissenschaft', u'informationsaufnahme', u'wissenserwerb', u'lernerfolg'], [u'verst\xe4ndnis', u'verarbeitung', u'information', u'ebene', u'lernende'], [u'belastung', u'verwendung', u'informationsaufnahme'], [u'belastung'], [u'gegensatz'], [u'f\xfclle', u'information', u'vorwissen'], [u'zusammenhang', u'vorwissen', u'kontext', u'umwelt', u'naturgesetze'], [u'informationsaufnahme', u'abgleichen', u'belastung', u'belastung'], [u'bereich', u'belastung', u'informationsflusses', u'ged\xe4chtnis'], [u'lernerfolg', u'verh\xe4ltnis'], [u'fallen', u'lernbelastung'], [u'folgende', u'modell'], [u'theorie', u'lernen', u'belastung', u'spicherkapazit\xe4t', u'arbeitsged\xe4chtnisses'], [u'form', u'belastung'], [], [u'einflu\xdf', u'lernen'], [u'rollen', u'ablenkung'], [u'beispiel', u'text', u'lernende', u'fokus', u'text', u'inhalt'], [u'beispiel', u'erkl\xe4rung', u'lernende', u'vorwissen'], [u'fall', u'lernende', u'informationsflut'], [u'belastung', u'art', u'lernen'], [u'verst\xe4ndnislernen', u'art', u'lernen', u'auswendiglernen', u'information', u'belastung', u'information', u'gelerntem', u'bezug'], [u'integration', u'wissen', u'verkn\xfcpfung', u'verst\xe4ndnis'], [u'kombination'], [u'belastung', u'gehirn', u'arbeitsged\xe4chtnis'], [u'theorie', u'verst\xe4ndnis', u'lernproze\xdf'], [u'gehirn', u'speichern', u'computer'], [u'speichern', u'kurzzeitspeicher', u'arbeitsspeicher', u'langzeitspeicher'], [u'kurzzeitspeicher', u'information', u'reizen', u'k\xf6rper'], [u'kapazit\xe4t'], [u'sinnesreize', u'exekutiv'], [u'exekutiv', u'information', u'fluss', u'sinnesreize', u'arbeitsspeicher', u'rest'], [u'arbeitsspeicher', u'ort', u'information'], [u'kapazit\xe4t', u'junks'], [u'junk', u'art', u'informationsb\xfcndel', u'information'], [u'arbeitsspeicher', u'information', u'vorwissen', u'langzeitspeicher'], [u'information', u'zeitraum', u'arbeitsspeicher'], [u'endstation', u'ged\xe4chtnis', u'langzeitspeicher', u'wissen', u'verkn\xfcpfen', u'arbeitsged\xe4chtnis'], [u'kurzzeitspeicher', u'information'], [u'langzeitspeicher'], [u'speichern', u'arbeitsged\xe4chtnisses', u'welchesinformationen'], [u'lehrkraft', u'speicherung'], [u'sch\xfcler', u'belastung'], [u'art', u'belastung'], [], [u'belastung', u'sch\xfcler', u'lernen'], [u'beispiel', u'l\xe4rmen', u'arbeitsatmosph\xe4re', u'ablenkung', u'art'], [u'lehrende'], [u'lehrende', u'belastung', u'lehrende', u'lernen'], [u'belastung', u'verstehen', u'thema', u'sch\xfcler'], [u'vorwissen', u'sch\xfcler'], [u'sch\xfcler', u'vorwissen', u'thema', u'arbeit', u'thema', u'gelerntem'], [u'belastung', u'sch\xfcler', u'lernen', u'verarbeiten', u'stoff'], [u'aufwand', u'verkn\xfcpfung', u'thema', u'verstehen', u'thema', u'einordnen', u'thema', u'gesamtzusammenhang', u'fach'], [u'belastung', u'lehrende', u'beispiel', u'erkl\xe4rung', u'pr\xe4sentation', u'umfang', u'zusammenhang', u'element'], [], [u'belastung', u'kapazit\xe4t', u'lernen'], [u'cognitiv', u'methode', u'\xfcberblick', u'lernen'], [u'erl\xe4uterung'], [u'belastung' ...

# %%
print(model)

# Get most similar words to a specific term
print(model.most_similar('vorwissen'))

# Get similarity between two terms
print(model.similarity('vorwissen', 'information'))

# Get vector representation of word
print(model.wv['vorwissen'])
print(model['information'])

# Play around with model
print(model.wv.most_similar(positive=['lehrer'], negative=['person']))

# Check what doesn't fit in the model
print(model.doesnt_match("arbeitsgedächnis information kurzeitspeicher langzeitspeicher".split()))
# Out:
# Word2Vec(vocab=124, size=100, alpha=0.025)
# [(u'information', 0.5339909791946411), (u'sch\xfcler', 0.5263341665267944), (u'thema', 0.471238374710083), (u'lernende', 0.46889516711235046), (u'bezug', 0.4609374403953552), (u'belastung', 0.4495766758918762), (u'text', 0.4446403682231903), (u'aufmerksamkeit', 0.43844881653785706), (u'seite', 0.43264949321746826), (u'person', 0.413810670375824)]
# 0.533990966602
# [ -6.46224990e-03   2.14940333e-03   2.59605562e-03   9.52842180e-03
#    4.60224925e-03  -2.76823342e-03  -3.51856649e-03   2.76701618e-03
#   -4.05324809e-03   4.40452900e-03   8.60047899e-03  -2.10578064e-03
#    6.81298319e-04   4.74661216e-03   7.04613980e-03  -4.19404963e-03
#   -4.58842563e-03  -1.33072631e-03  -6.63532061e-04   3.82143119e-03
#    7.67149962e-03   1.23298750e-03  -1.79579051e-03  -3.99582135e-03
#   -7.45459693e-04   5.84665826e-03   3.55368573e-03   1.83640033e-04
#   -1.59388047e-03  -1.83257274e-03  -2.97513581e-03  -6.12656772e-03
#    7.64889596e-03  -4.29744506e-03   5.02096210e-03   3.29640950e-03
#    1.04144996e-03  -3.62351158e-04   3.96671565e-03   2.83495709e-03
#   -5.11233509e-03   5.73106343e-03  -1.04346238e-02   4.33662534e-03
#    3.44827143e-03   3.80151614e-04   5.24639338e-03  -2.47910386e-03
#   -3.19655752e-03  -2.63655616e-04  -5.96163329e-03  -1.68500142e-03
#   -3.81954043e-04   3.85844905e-04  -7.21078878e-03  -4.01217397e-03
#   -1.05445005e-03   2.74000200e-03  -3.44020431e-04  -3.63914366e-03
#    5.73825557e-03  -8.62160086e-05  -3.20019783e-04  -3.18228244e-03
#    7.96687324e-04   5.41495485e-03  -7.27439811e-03   3.09535977e-03
#   -3.85080650e-03  -3.77494050e-03   1.66391488e-03   1.57420046e-03
#    4.17795934e-04   3.87422019e-03   1.86749210e-04  -6.75693667e-03
#   -3.00351367e-03  -3.45166540e-03   3.84162716e-03  -2.10057478e-03
#   -9.25981847e-04  -4.09132335e-03  -5.66152681e-04  -1.97423768e-04
#   -2.62030703e-03   5.86607028e-03  -3.42371035e-03  -9.84095386e-04
#    4.44260193e-03  -1.36572798e-03  -6.35548821e-03   9.65847925e-04
#   -1.85215566e-03   5.66661218e-03  -2.35256040e-03  -2.11378396e-03
#    7.14483846e-04   1.17849291e-03  -1.55191950e-03  -2.68613175e-03]
# [-0.00474041  0.00103234  0.01147542  0.00700061 -0.00254729  0.00528553
#  -0.00644632 -0.00110312  0.00257567 -0.00380201  0.00121643 -0.0053824
#  -0.00275694  0.00083686  0.00758091 -0.00302522 -0.00149595 -0.0044396
#  -0.00469652 -0.00232232  0.0117573   0.0068799   0.00379603 -0.00446487
#   0.00462954  0.00124847 -0.00266341 -0.0019543  -0.00137299 -0.01014285
#  -0.00416656 -0.00615529  0.00807802 -0.00326939  0.00441323 -0.00232108
#   0.00117253 -0.00195558  0.00450579  0.00409441  0.00085156  0.00226401
#  -0.01144405 -0.00153742  0.00195555  0.00022641  0.00966091  0.00435441
#  -0.00632819  0.00221403  0.00298216 -0.00695336 -0.00565169 -0.00034337
#  -0.00418709 -0.00370911  0.00128607 -0.00126933 -0.00312852 -0.00200688
#   0.00766848  0.00501777 -0.0027696  -0.00271769  0.0018566   0.00232523
#   0.00061165  0.00183568 -0.00993138 -0.01037528  0.00338125 -0.00386492
#  -0.00764665  0.00255745 -0.0067458  -0.00547055 -0.00069203 -0.00257039
#   0.00825242 -0.00478634  0.00502671 -0.00393459  0.00015678 -0.00355158
#  -0.00484489  0.01020972  0.00277267  0.0002691   0.00478627  0.00247583
#  -0.00220595  0.00079039 -0.00420361 -0.00359542 -0.00298261  0.00770095
#   0.00516719  0.00667072  0.00492512 -0.0008704 ]
# [(u'speicherung', 0.10714629292488098), (u'effekt', 0.09642212092876434), (u'erkl\xe4rung', 0.09172812849283218), (u'pr\xe4sentation', 0.0831574946641922), (u'bereich', 0.0776066780090332), (u'einflu\xdf', 0.07127410918474197), (u'bildungswissenschaft', 0.0691365897655487), (u'speicherkapazit\xe4t', 0.06820656359195709), (u'lerneffekt', 0.06314762681722641), (u'folie', 0.05614813417196274)]
# langzeitspeicher

# %%
lda = LdaModel(corpus, num_topics=1, id2word = dictionary)

# %%
for topic, word in lda.show_topics():
    print(word)
    print('\n')
# Out:
# 0.062*"information" + 0.056*"belastung" + 0.028*"lernen" + 0.026*"vorwissen" + 0.021*"lernende" + 0.018*"arbeitsgedächtnis" + 0.017*"beispiel" + 0.016*"gedächtnis" + 0.014*"langzeitgedächtnis" + 0.014*"arbeitsspeicher"
